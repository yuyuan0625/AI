# %%
import torch
from torch.autograd import Variable

# %%
def to_var(x):
  if torch.cuda.is_available():
    x = x.cuda()
  return Variable(x)

# %%
import torchvision.datasets as dsets
import torchvision.transforms as transforms

# %%
transform = transforms.Compose([transforms.ToTensor(),              
                  transforms.Normalize(mean=0.5,std=0.5)])

# %%
train_dataset = dsets.MNIST(root='./data',
                train=True,
                transform=transform,
                download=True)
test_dataset = dsets.MNIST(root='./data',
                train=False,
                transform=transform,
                download=False)

# %%
import torch.utils.data as Data

# %%
data_loader = Data.DataLoader(dataset=train_dataset,
                 batch_size = 100,
                 shuffle=True)

# %%
import torch.nn as nn

# %%
D = nn.Sequential(
    nn.Linear(28*28, 256),             
    nn.LeakyReLU(0.2),             
    nn.Linear(256, 256),             
    nn.LeakyReLU(0.2),
    nn.Linear(256, 1),    
    nn.Sigmoid()
)

# %%
G = nn.Sequential(
    nn.Linear(64, 256),               
    nn.LeakyReLU(0.2),
    nn.Linear(256, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 28*28),    
    nn.Tanh()                     
)

# %%
if torch.cuda.is_available():
  D.cuda()
  G.cuda()

# %%
loss_fn = nn.BCELoss()
d_opt = torch.optim.Adam(D.parameters(),lr=0.0003)
g_opt = torch.optim.Adam(G.parameters(),lr=0.0003)

# %%
from torchvision.utils import save_image

# %%
def denorm(x):
  out = (x+1)/2                     #denormalize
  return out.clamp(0,1)

# %%
for epoch in range(200):
  for i, (images,_) in enumerate(data_loader):      #enumerate給編號
    batch_size = images.size(0)
    images = to_var(images.view(batch_size, -1))

    real_labels = to_var(torch.ones(batch_size,1))
    fake_labels = to_var(torch.zeros(batch_size,1))

    outputs = D(images)
    d_loss_real = loss_fn(outputs, real_labels)
    real_score = outputs
    
    z = to_var(torch.randn(batch_size, 64))       #randn 有正有負 產生tensor
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = loss_fn(outputs, fake_labels)
    fake_score = outputs

    d_loss = d_loss_real+d_loss_fake
    D.zero_grad()
    d_loss.backward()
    d_opt.step()

    z = to_var(torch.randn(batch_size, 64))
    fake_images = G(z)
    outputs = D(fake_images)

    g_loss = loss_fn(outputs, real_labels)
    D.zero_grad()
    G.zero_grad()
    g_loss.backward()
    g_opt.step()

    if (i+1)%300 == 0:
      print("Epoch %-3d, batch: %-3d, d_loss: %-.4f, g_loss: %-.4f,"
      "D(x): %-.2f, D(G(z)): %-.2f"
      %(epoch,i+1,d_loss.data,g_loss.data,real_score.data.mean(),fake_score.data.mean()))
  if epoch == 0:
    images = images.view(images.size(0), 1, 28, 28)
    save_image(denorm(images),"/content/data/real_images.png")
  fake_images = fake_images.view(fake_images.size(0), 1, 28, 28)
  save_image(denorm(fake_images),"/content/data/fake_images-%d.png"%(epoch+1))
# Out:
# Epoch 0  , batch: 300, d_loss: 0.2485, g_loss: 4.3422,D(x): 0.98, D(G(z)): 0.16
# Epoch 0  , batch: 600, d_loss: 1.0102, g_loss: 1.8690,D(x): 0.80, D(G(z)): 0.45
# Epoch 1  , batch: 300, d_loss: 0.8826, g_loss: 4.1570,D(x): 0.77, D(G(z)): 0.26
# Epoch 1  , batch: 600, d_loss: 1.6384, g_loss: 2.1110,D(x): 0.67, D(G(z)): 0.55
# Epoch 2  , batch: 300, d_loss: 1.3412, g_loss: 1.2795,D(x): 0.64, D(G(z)): 0.52
# Epoch 2  , batch: 600, d_loss: 0.4454, g_loss: 1.9359,D(x): 0.85, D(G(z)): 0.23
# Epoch 3  , batch: 300, d_loss: 0.5015, g_loss: 2.7302,D(x): 0.89, D(G(z)): 0.26
# Epoch 3  , batch: 600, d_loss: 1.7415, g_loss: 2.1919,D(x): 0.62, D(G(z)): 0.41
# Epoch 4  , batch: 300, d_loss: 0.8704, g_loss: 1.8869,D(x): 0.75, D(G(z)): 0.27
# Epoch 4  , batch: 600, d_loss: 0.9640, g_loss: 3.7414,D(x): 0.67, D(G(z)): 0.24
# Epoch 5  , batch: 300, d_loss: 1.3091, g_loss: 1.4398,D(x): 0.71, D(G(z)): 0.41
# Epoch 5  , batch: 600, d_loss: 1.0260, g_loss: 1.6658,D(x): 0.67, D(G(z)): 0.36
# Epoch 6  , batch: 300, d_loss: 0.3484, g_loss: 2.7882,D(x): 0.83, D(G(z)): 0.11
# Epoch 6  , batch: 600, d_loss: 1.6619, g_loss: 1.0226,D(x): 0.61, D(G(z)): 0.49
# Epoch 7  , batch: 300, d_loss: 0.8523, g_loss: 1.6220,D(x): 0.73, D(G(z)): 0.29
# Epoch 7  , batch: 600, d_loss: 1.0986, g_loss: 1.8288,D(x): 0.59, D(G(z)): 0.18
# Epoch 8  , batch: 300, d_loss: 0.6086, g_loss: 2.9414,D(x): 0.83, D(G(z)): 0.26
# Epoch 8  , batch: 600, d_loss: 1.0708, g_loss: 2.2855,D(x): 0.64, D(G(z)): 0.29
# Epoch 9  , batch: 300, d_loss: 0.7141, g_loss: 1.9411,D(x): 0.74, D(G(z)): 0.26
# Epoch 9  , batch: 600, d_loss: 0.3811, g_loss: 3.4380,D(x): 0.88, D(G(z)): 0.17
# Epoch 10 , batch: 300, d_loss: 0.2787, g_loss: 2.9286,D(x): 0.91, D(G(z)): 0.11
# Epoch 10 , batch: 600, d_loss: 0.5259, g_loss: 3.4306,D(x): 0.80, D(G(z)): 0.07
# Epoch 11 , batch: 300, d_loss: 0.5342, g_loss: 2.6082,D(x): 0.82, D(G(z)): 0.11
# Epoch 11 , batch: 600, d_loss: 0.9580, g_loss: 4.0146,D(x): 0.78, D(G(z)): 0.19
# Epoch 12 , batch: 300, d_loss: 0.4539, g_loss: 3.1340,D(x): 0.88, D(G(z)): 0.15
# Epoch 12 , batch: 600, d_loss: 0.7908, g_loss: 2.5808,D(x): 0.77, D(G(z)): 0.21
# Epoch 13 , batch: 300, d_loss: 0.7425, g_loss: 2.7017,D(x): 0.73, D(G(z)): 0.15
# Epoch 13 , batch: 600, d_loss: 0.4087, g_loss: 2.9688,D(x): 0.88, D(G(z)): 0.17
# Epoch 14 , batch: 300, d_loss: 0.6617, g_loss: 3.0819,D(x): 0.75, D(G(z)): 0.13
# Epoch 14 , batch: 600, d_loss: 0.7198, g_loss: 2.3598,D(x): 0.81, D(G(z)): 0.28
# Epoch 15 , batch: 300, d_loss: 0.4852, g_loss: 3.1901,D(x): 0.83, D(G(z)): 0.14
# Epoch 15 , batch: 600, d_loss: 0.8882, g_loss: 1.7967,D(x): 0.75, D(G(z)): 0.25
# Epoch 16 , batch: 300, d_loss: 0.6490, g_loss: 2.1737,D(x): 0.75, D(G(z)): 0.22
# Epoch 16 , batch: 600, d_loss: 0.8332, g_loss: 2.4280,D(x): 0.67, D(G(z)): 0.18
# Epoch 17 , batch: 300, d_loss: 0.8140, g_loss: 1.5911,D(x): 0.72, D(G(z)): 0.25
# Epoch 17 , batch: 600, d_loss: 0.8276, g_loss: 1.8846,D(x): 0.71, D(G(z)): 0.27
# Epoch 18 , batch: 300, d_loss: 0.7699, g_loss: 1.9603,D(x): 0.75, D(G(z)): 0.24
# Epoch 18 , batch: 600, d_loss: 1.1375, g_loss: 1.6839,D(x): 0.67, D(G(z)): 0.30
# Epoch 19 , batch: 300, d_loss: 0.5235, g_loss: 2.6483,D(x): 0.82, D(G(z)): 0.17
# Epoch 19 , batch: 600, d_loss: 0.7239, g_loss: 2.0570,D(x): 0.86, D(G(z)): 0.31
# Epoch 20 , batch: 300, d_loss: 1.2351, g_loss: 2.0599,D(x): 0.73, D(G(z)): 0.40
# Epoch 20 , batch: 600, d_loss: 0.8274, g_loss: 2.1576,D(x): 0.75, D(G(z)): 0.27
# Epoch 21 , batch: 300, d_loss: 0.7366, g_loss: 1.9162,D(x): 0.81, D(G(z)): 0.28
# Epoch 21 , batch: 600, d_loss: 0.5470, g_loss: 2.7401,D(x): 0.78, D(G(z)): 0.15
# Epoch 22 , batch: 300, d_loss: 0.9386, g_loss: 1.7917,D(x): 0.66, D(G(z)): 0.19
# Epoch 22 , batch: 600, d_loss: 0.7516, g_loss: 1.5327,D(x): 0.83, D(G(z)): 0.32
# Epoch 23 , batch: 300, d_loss: 0.7646, g_loss: 2.6417,D(x): 0.76, D(G(z)): 0.18
# Epoch 23 , batch: 600, d_loss: 0.9192, g_loss: 1.7801,D(x): 0.72, D(G(z)): 0.30
# Epoch 24 , batch: 300, d_loss: 1.0621, g_loss: 1.6432,D(x): 0.76, D(G(z)): 0.37
# Epoch 24 , batch: 600, d_loss: 0.5370, g_loss: 2.4689,D(x): 0.75, D(G(z)): 0.12
# Epoch 25 , batch: 300, d_loss: 0.7433, g_loss: 1.7440,D(x): 0.76, D(G(z)): 0.29
# Epoch 25 , batch: 600, d_loss: 1.0559, g_loss: 1.7592,D(x): 0.71, D(G(z)): 0.38
# Epoch 26 , batch: 300, d_loss: 1.1461, g_loss: 2.6843,D(x): 0.79, D(G(z)): 0.41
# Epoch 26 , batch: 600, d_loss: 1.0141, g_loss: 1.8083,D(x): 0.72, D(G(z)): 0.31
# Epoch 27 , batch: 300, d_loss: 0.9890, g_loss: 1.7125,D(x): 0.70, D(G(z)): 0.29
# Epoch 27 , batch: 600, d_loss: 0.8192, g_loss: 2.4261,D(x): 0.70, D(G(z)): 0.22
# Epoch 28 , batch: 300, d_loss: 0.8670, g_loss: 1.4242,D(x): 0.75, D(G(z)): 0.33
# Epoch 28 , batch: 600, d_loss: 0.7595, g_loss: 1.7825,D(x): 0.73, D(G(z)): 0.24
# Epoch 29 , batch: 300, d_loss: 0.9773, g_loss: 1.7758,D(x): 0.68, D(G(z)): 0.26
# Epoch 29 , batch: 600, d_loss: 0.8416, g_loss: 1.3273,D(x): 0.71, D(G(z)): 0.27
# Epoch 30 , batch: 300, d_loss: 0.9378, g_loss: 1.5576,D(x): 0.64, D(G(z)): 0.25
# Epoch 30 , batch: 600, d_loss: 1.0731, g_loss: 1.4572,D(x): 0.65, D(G(z)): 0.31
# Epoch 31 , batch: 300, d_loss: 0.8290, g_loss: 1.8601,D(x): 0.74, D(G(z)): 0.30
# Epoch 31 , batch: 600, d_loss: 1.0073, g_loss: 1.3435,D(x): 0.65, D(G(z)): 0.30
# Epoch 32 , batch: 300, d_loss: 0.9043, g_loss: 1.6129,D(x): 0.72, D(G(z)): 0.31
# Epoch 32 , batch: 600, d_loss: 0.9465, g_loss: 2.0466,D(x): 0.61, D(G(z)): 0.18
# Epoch 33 , batch: 300, d_loss: 0.7776, g_loss: 2.2319,D(x): 0.69, D(G(z)): 0.21
# Epoch 33 , batch: 600, d_loss: 0.7821, g_loss: 1.8999,D(x): 0.74, D(G(z)): 0.27
# Epoch 34 , batch: 300, d_loss: 0.8482, g_loss: 2.2454,D(x): 0.73, D(G(z)): 0.26
# Epoch 34 , batch: 600, d_loss: 0.8621, g_loss: 1.7712,D(x): 0.71, D(G(z)): 0.28
# Epoch 35 , batch: 300, d_loss: 0.9256, g_loss: 2.1922,D(x): 0.74, D(G(z)): 0.33
# Epoch 35 , batch: 600, d_loss: 0.9770, g_loss: 1.6840,D(x): 0.67, D(G(z)): 0.31
# Epoch 36 , batch: 300, d_loss: 0.8446, g_loss: 1.6423,D(x): 0.72, D(G(z)): 0.28
# Epoch 36 , batch: 600, d_loss: 0.6764, g_loss: 1.8170,D(x): 0.72, D(G(z)): 0.19
# Epoch 37 , batch: 300, d_loss: 1.0806, g_loss: 1.3149,D(x): 0.79, D(G(z)): 0.47
# Epoch 37 , batch: 600, d_loss: 0.8229, g_loss: 1.8924,D(x): 0.66, D(G(z)): 0.18
# Epoch 38 , batch: 300, d_loss: 0.8427, g_loss: 2.1327,D(x): 0.65, D(G(z)): 0.20
# Epoch 38 , batch: 600, d_loss: 0.8385, g_loss: 1.8511,D(x): 0.81, D(G(z)): 0.37
# Epoch 39 , batch: 300, d_loss: 0.8899, g_loss: 1.6214,D(x): 0.69, D(G(z)): 0.29
# Epoch 39 , batch: 600, d_loss: 1.0549, g_loss: 1.4491,D(x): 0.71, D(G(z)): 0.36
# Epoch 40 , batch: 300, d_loss: 0.7609, g_loss: 1.7980,D(x): 0.80, D(G(z)): 0.33
# Epoch 40 , batch: 600, d_loss: 0.9295, g_loss: 1.8353,D(x): 0.68, D(G(z)): 0.29
# Epoch 41 , batch: 300, d_loss: 0.8379, g_loss: 1.6090,D(x): 0.71, D(G(z)): 0.30
# Epoch 41 , batch: 600, d_loss: 0.9686, g_loss: 2.0471,D(x): 0.57, D(G(z)): 0.14
# Epoch 42 , batch: 300, d_loss: 0.8267, g_loss: 1.6983,D(x): 0.80, D(G(z)): 0.32
# Epoch 42 , batch: 600, d_loss: 0.9144, g_loss: 1.5123,D(x): 0.71, D(G(z)): 0.31
# Epoch 43 , batch: 300, d_loss: 0.8266, g_loss: 1.8903,D(x): 0.72, D(G(z)): 0.26
# Epoch 43 , batch: 600, d_loss: 0.8453, g_loss: 1.8165,D(x): 0.68, D(G(z)): 0.21
# Epoch 44 , batch: 300, d_loss: 0.7814, g_loss: 1.7017,D(x): 0.71, D(G(z)): 0.25
# Epoch 44 , batch: 600, d_loss: 0.8336, g_loss: 1.7714,D(x): 0.66, D(G(z)): 0.21
# Epoch 45 , batch: 300, d_loss: 0.7033, g_loss: 2.2179,D(x): 0.74, D(G(z)): 0.21
# Epoch 45 , batch: 600, d_loss: 0.9529, g_loss: 1.8273,D(x): 0.71, D(G(z)): 0.34
# Epoch 46 , batch: 300, d_loss: 0.6812, g_loss: 1.4140,D(x): 0.74, D(G(z)): 0.23
# Epoch 46 , batch: 600, d_loss: 0.8662, g_loss: 1.8673,D(x): 0.75, D(G(z)): 0.33
# Epoch 47 , batch: 300, d_loss: 0.7233, g_loss: 1.9197,D(x): 0.74, D(G(z)): 0.26
# Epoch 47 , batch: 600, d_loss: 0.7405, g_loss: 1.6422,D(x): 0.73, D(G(z)): 0.24
# Epoch 48 , batch: 300, d_loss: 1.0589, g_loss: 1.9621,D(x): 0.77, D(G(z)): 0.40
# Epoch 48 , batch: 600, d_loss: 0.8182, g_loss: 1.8765,D(x): 0.74, D(G(z)): 0.31
# Epoch 49 , batch: 300, d_loss: 0.6658, g_loss: 1.8267,D(x): 0.77, D(G(z)): 0.24
# Epoch 49 , batch: 600, d_loss: 0.8030, g_loss: 2.0442,D(x): 0.68, D(G(z)): 0.19
# Epoch 50 , batch: 300, d_loss: 0.6432, g_loss: 2.0917,D(x): 0.81, D(G(z)): 0.27
# Epoch 50 , batch: 600, d_loss: 0.7569, g_loss: 1.6495,D(x): 0.72, D(G(z)): 0.25
# Epoch 51 , batch: 300, d_loss: 0.8765, g_loss: 1.8704,D(x): 0.68, D(G(z)): 0.25
# Epoch 51 , batch: 600, d_loss: 0.7778, g_loss: 1.2858,D(x): 0.78, D(G(z)): 0.29
# Epoch 52 , batch: 300, d_loss: 0.8261, g_loss: 1.7989,D(x): 0.70, D(G(z)): 0.25
# Epoch 52 , batch: 600, d_loss: 0.8190, g_loss: 1.8292,D(x): 0.78, D(G(z)): 0.33
# Epoch 53 , batch: 300, d_loss: 0.8248, g_loss: 1.5914,D(x): 0.75, D(G(z)): 0.30
# Epoch 53 , batch: 600, d_loss: 0.9423, g_loss: 1.5810,D(x): 0.74, D(G(z)): 0.34
# Epoch 54 , batch: 300, d_loss: 0.8932, g_loss: 2.3002,D(x): 0.72, D(G(z)): 0.27
# Epoch 54 , batch: 600, d_loss: 0.8310, g_loss: 1.7049,D(x): 0.78, D(G(z)): 0.34
# Epoch 55 , batch: 300, d_loss: 0.7429, g_loss: 1.6756,D(x): 0.75, D(G(z)): 0.26
# Epoch 55 , batch: 600, d_loss: 0.7583, g_loss: 1.6558,D(x): 0.76, D(G(z)): 0.28
# Epoch 56 , batch: 300, d_loss: 0.6501, g_loss: 1.9475,D(x): 0.78, D(G(z)): 0.26
# Epoch 56 , batch: 600, d_loss: 0.8424, g_loss: 1.5658,D(x): 0.73, D(G(z)): 0.29
# Epoch 57 , batch: 300, d_loss: 0.8733, g_loss: 1.7099,D(x): 0.77, D(G(z)): 0.35
# Epoch 57 , batch: 600, d_loss: 0.9955, g_loss: 1.7038,D(x): 0.67, D(G(z)): 0.30
# Epoch 58 , batch: 300, d_loss: 0.8278, g_loss: 1.5061,D(x): 0.73, D(G(z)): 0.30
# Epoch 58 , batch: 600, d_loss: 0.9228, g_loss: 1.5862,D(x): 0.65, D(G(z)): 0.24
# Epoch 59 , batch: 300, d_loss: 0.9171, g_loss: 1.8461,D(x): 0.65, D(G(z)): 0.21
# Epoch 59 , batch: 600, d_loss: 0.9885, g_loss: 1.6195,D(x): 0.75, D(G(z)): 0.36
# Epoch 60 , batch: 300, d_loss: 0.8355, g_loss: 1.6070,D(x): 0.73, D(G(z)): 0.27
# Epoch 60 , batch: 600, d_loss: 0.9016, g_loss: 1.9115,D(x): 0.71, D(G(z)): 0.30
# Epoch 61 , batch: 300, d_loss: 1.0720, g_loss: 1.6466,D(x): 0.69, D(G(z)): 0.34
# Epoch 61 , batch: 600, d_loss: 0.7013, g_loss: 1.7172,D(x): 0.72, D(G(z)): 0.24
# Epoch 62 , batch: 300, d_loss: 0.9604, g_loss: 1.8093,D(x): 0.78, D(G(z)): 0.39
# Epoch 62 , batch: 600, d_loss: 0.7886, g_loss: 2.2399,D(x): 0.76, D(G(z)): 0.29
# Epoch 63 , batch: 300, d_loss: 1.0118, g_loss: 1.5694,D(x): 0.82, D(G(z)): 0.45
# Epoch 63 , batch: 600, d_loss: 0.9500, g_loss: 1.6162,D(x): 0.71, D(G(z)): 0.32
# Epoch 64 , batch: 300, d_loss: 0.8915, g_loss: 1.5328,D(x): 0.68, D(G(z)): 0.25
# Epoch 64 , batch: 600, d_loss: 0.8344, g_loss: 1.6175,D(x): 0.73, D(G(z)): 0.29
# Epoch 65 , batch: 300, d_loss: 0.7991, g_loss: 1.5776,D(x): 0.66, D(G(z)): 0.17
# Epoch 65 , batch: 600, d_loss: 0.7877, g_loss: 1.7390,D(x): 0.74, D(G(z)): 0.29
# Epoch 66 , batch: 300, d_loss: 0.7138, g_loss: 1.4925,D(x): 0.72, D(G(z)): 0.23
# Epoch 66 , batch: 600, d_loss: 0.7850, g_loss: 1.8372,D(x): 0.79, D(G(z)): 0.32
# Epoch 67 , batch: 300, d_loss: 0.6846, g_loss: 1.6391,D(x): 0.82, D(G(z)): 0.28
# Epoch 67 , batch: 600, d_loss: 0.8667, g_loss: 1.6414,D(x): 0.70, D(G(z)): 0.28
# Epoch 68 , batch: 300, d_loss: 0.7547, g_loss: 2.0365,D(x): 0.79, D(G(z)): 0.31
# Epoch 68 , batch: 600, d_loss: 1.0071, g_loss: 1.9831,D(x): 0.62, D(G(z)): 0.23
# Epoch 69 , batch: 300, d_loss: 0.9227, g_loss: 1.4419,D(x): 0.77, D(G(z)): 0.36
# Epoch 69 , batch: 600, d_loss: 0.8308, g_loss: 1.5194,D(x): 0.71, D(G(z)): 0.23
# Epoch 70 , batch: 300, d_loss: 0.9079, g_loss: 1.4086,D(x): 0.74, D(G(z)): 0.35
# Epoch 70 , batch: 600, d_loss: 0.9025, g_loss: 1.5098,D(x): 0.77, D(G(z)): 0.36
# Epoch 71 , batch: 300, d_loss: 0.8289, g_loss: 2.0041,D(x): 0.68, D(G(z)): 0.25
# Epoch 71 , batch: 600, d_loss: 0.8728, g_loss: 1.5403,D(x): 0.72, D(G(z)): 0.30
# Epoch 72 , batch: 300, d_loss: 0.6866, g_loss: 1.6551,D(x): 0.80, D(G(z)): 0.29
# Epoch 72 , batch: 600, d_loss: 0.7682, g_loss: 1.3991,D(x): 0.68, D(G(z)): 0.21
# Epoch 73 , batch: 300, d_loss: 0.8516, g_loss: 1.1481,D(x): 0.75, D(G(z)): 0.31
# Epoch 73 , batch: 600, d_loss: 1.0534, g_loss: 1.3742,D(x): 0.65, D(G(z)): 0.31
# Epoch 74 , batch: 300, d_loss: 0.8778, g_loss: 1.4820,D(x): 0.82, D(G(z)): 0.40
# Epoch 74 , batch: 600, d_loss: 0.7601, g_loss: 1.9286,D(x): 0.69, D(G(z)): 0.23
# Epoch 75 , batch: 300, d_loss: 0.7523, g_loss: 1.6912,D(x): 0.75, D(G(z)): 0.28
# Epoch 75 , batch: 600, d_loss: 0.8885, g_loss: 1.7110,D(x): 0.73, D(G(z)): 0.31
# Epoch 76 , batch: 300, d_loss: 0.9811, g_loss: 2.0161,D(x): 0.62, D(G(z)): 0.21
# Epoch 76 , batch: 600, d_loss: 0.9776, g_loss: 1.7243,D(x): 0.69, D(G(z)): 0.32
# Epoch 77 , batch: 300, d_loss: 0.7254, g_loss: 1.7426,D(x): 0.74, D(G(z)): 0.26
# Epoch 77 , batch: 600, d_loss: 0.9954, g_loss: 1.4264,D(x): 0.67, D(G(z)): 0.32
# Epoch 78 , batch: 300, d_loss: 0.9384, g_loss: 1.6685,D(x): 0.64, D(G(z)): 0.24
# Epoch 78 , batch: 600, d_loss: 0.9286, g_loss: 1.6540,D(x): 0.71, D(G(z)): 0.32
# Epoch 79 , batch: 300, d_loss: 0.9039, g_loss: 1.3313,D(x): 0.78, D(G(z)): 0.39
# Epoch 79 , batch: 600, d_loss: 0.7929, g_loss: 1.8091,D(x): 0.77, D(G(z)): 0.30
# Epoch 80 , batch: 300, d_loss: 0.9424, g_loss: 1.5718,D(x): 0.75, D(G(z)): 0.34
# Epoch 80 , batch: 600, d_loss: 0.9677, g_loss: 1.6527,D(x): 0.63, D(G(z)): 0.26
# Epoch 81 , batch: 300, d_loss: 0.9200, g_loss: 1.4657,D(x): 0.64, D(G(z)): 0.26
# Epoch 81 , batch: 600, d_loss: 0.9038, g_loss: 1.0194,D(x): 0.70, D(G(z)): 0.30
# Epoch 82 , batch: 300, d_loss: 0.7672, g_loss: 1.6683,D(x): 0.83, D(G(z)): 0.35
# Epoch 82 , batch: 600, d_loss: 0.8440, g_loss: 1.3180,D(x): 0.73, D(G(z)): 0.29
# Epoch 83 , batch: 300, d_loss: 0.7056, g_loss: 1.8099,D(x): 0.75, D(G(z)): 0.25
# Epoch 83 , batch: 600, d_loss: 0.8631, g_loss: 1.6249,D(x): 0.75, D(G(z)): 0.32
# Epoch 84 , batch: 300, d_loss: 0.7857, g_loss: 1.1263,D(x): 0.72, D(G(z)): 0.25
# Epoch 84 , batch: 600, d_loss: 0.8310, g_loss: 1.5871,D(x): 0.74, D(G(z)): 0.32
# Epoch 85 , batch: 300, d_loss: 0.9999, g_loss: 1.7911,D(x): 0.70, D(G(z)): 0.35
# Epoch 85 , batch: 600, d_loss: 1.0780, g_loss: 1.6247,D(x): 0.61, D(G(z)): 0.28
# Epoch 86 , batch: 300, d_loss: 0.8502, g_loss: 1.5121,D(x): 0.75, D(G(z)): 0.30
# Epoch 86 , batch: 600, d_loss: 1.0237, g_loss: 1.8404,D(x): 0.64, D(G(z)): 0.30
# Epoch 87 , batch: 300, d_loss: 0.8416, g_loss: 1.7756,D(x): 0.75, D(G(z)): 0.32
# Epoch 87 , batch: 600, d_loss: 0.7710, g_loss: 1.6178,D(x): 0.71, D(G(z)): 0.25
# Epoch 88 , batch: 300, d_loss: 0.9395, g_loss: 1.7203,D(x): 0.72, D(G(z)): 0.34
# Epoch 88 , batch: 600, d_loss: 0.8180, g_loss: 1.6273,D(x): 0.75, D(G(z)): 0.32
# Epoch 89 , batch: 300, d_loss: 0.9026, g_loss: 1.6319,D(x): 0.79, D(G(z)): 0.37
# Epoch 89 , batch: 600, d_loss: 0.9573, g_loss: 1.7102,D(x): 0.69, D(G(z)): 0.32
# Epoch 90 , batch: 300, d_loss: 0.8789, g_loss: 1.6389,D(x): 0.67, D(G(z)): 0.27
# Epoch 90 , batch: 600, d_loss: 0.9817, g_loss: 1.6540,D(x): 0.70, D(G(z)): 0.33
# Epoch 91 , batch: 300, d_loss: 0.9423, g_loss: 1.6451,D(x): 0.62, D(G(z)): 0.21
# Epoch 91 , batch: 600, d_loss: 0.9523, g_loss: 1.2083,D(x): 0.70, D(G(z)): 0.33
# Epoch 92 , batch: 300, d_loss: 0.9241, g_loss: 1.4813,D(x): 0.73, D(G(z)): 0.33
# Epoch 92 , batch: 600, d_loss: 0.9356, g_loss: 1.7165,D(x): 0.71, D(G(z)): 0.32
# Epoch 93 , batch: 300, d_loss: 0.7202, g_loss: 1.9282,D(x): 0.81, D(G(z)): 0.32
# Epoch 93 , batch: 600, d_loss: 0.9036, g_loss: 1.2728,D(x): 0.66, D(G(z)): 0.29
# Epoch 94 , batch: 300, d_loss: 0.8478, g_loss: 1.6572,D(x): 0.73, D(G(z)): 0.29
# Epoch 94 , batch: 600, d_loss: 0.7536, g_loss: 1.8331,D(x): 0.73, D(G(z)): 0.26
# Epoch 95 , batch: 300, d_loss: 0.8012, g_loss: 1.6223,D(x): 0.70, D(G(z)): 0.24
# Epoch 95 , batch: 600, d_loss: 1.0405, g_loss: 1.7144,D(x): 0.72, D(G(z)): 0.36
# Epoch 96 , batch: 300, d_loss: 0.8762, g_loss: 1.7454,D(x): 0.71, D(G(z)): 0.28
# Epoch 96 , batch: 600, d_loss: 0.8713, g_loss: 1.6690,D(x): 0.67, D(G(z)): 0.26
# Epoch 97 , batch: 300, d_loss: 0.9492, g_loss: 1.8149,D(x): 0.64, D(G(z)): 0.28
# Epoch 97 , batch: 600, d_loss: 0.9676, g_loss: 1.8475,D(x): 0.73, D(G(z)): 0.33
# Epoch 98 , batch: 300, d_loss: 0.8145, g_loss: 1.9056,D(x): 0.73, D(G(z)): 0.28
# Epoch 98 , batch: 600, d_loss: 0.8452, g_loss: 1.1980,D(x): 0.73, D(G(z)): 0.32
# Epoch 99 , batch: 300, d_loss: 0.7927, g_loss: 1.3518,D(x): 0.77, D(G(z)): 0.32
# Epoch 99 , batch: 600, d_loss: 0.9067, g_loss: 1.3100,D(x): 0.63, D(G(z)): 0.24
# Epoch 100, batch: 300, d_loss: 0.8266, g_loss: 1.4075,D(x): 0.71, D(G(z)): 0.26
# Epoch 100, batch: 600, d_loss: 0.8883, g_loss: 1.4899,D(x): 0.73, D(G(z)): 0.33
# Epoch 101, batch: 300, d_loss: 1.0051, g_loss: 1.7675,D(x): 0.66, D(G(z)): 0.29
# Epoch 101, batch: 600, d_loss: 0.8700, g_loss: 1.8139,D(x): 0.73, D(G(z)): 0.32
# Epoch 102, batch: 300, d_loss: 0.9601, g_loss: 1.6508,D(x): 0.69, D(G(z)): 0.31
# Epoch 102, batch: 600, d_loss: 0.9143, g_loss: 1.6712,D(x): 0.67, D(G(z)): 0.28
# Epoch 103, batch: 300, d_loss: 0.9688, g_loss: 1.7540,D(x): 0.62, D(G(z)): 0.23
# Epoch 103, batch: 600, d_loss: 0.9719, g_loss: 1.5087,D(x): 0.77, D(G(z)): 0.38
# Epoch 104, batch: 300, d_loss: 0.8067, g_loss: 1.6899,D(x): 0.72, D(G(z)): 0.29
# Epoch 104, batch: 600, d_loss: 0.9330, g_loss: 1.6272,D(x): 0.68, D(G(z)): 0.29
# Epoch 105, batch: 300, d_loss: 0.8629, g_loss: 1.5776,D(x): 0.74, D(G(z)): 0.32
# Epoch 105, batch: 600, d_loss: 0.9483, g_loss: 1.7650,D(x): 0.70, D(G(z)): 0.31
# Epoch 106, batch: 300, d_loss: 1.0375, g_loss: 1.7347,D(x): 0.79, D(G(z)): 0.43
# Epoch 106, batch: 600, d_loss: 0.9024, g_loss: 1.7149,D(x): 0.69, D(G(z)): 0.31
# Epoch 107, batch: 300, d_loss: 0.9713, g_loss: 1.4824,D(x): 0.71, D(G(z)): 0.33
# Epoch 107, batch: 600, d_loss: 0.9226, g_loss: 1.6209,D(x): 0.69, D(G(z)): 0.29
# Epoch 108, batch: 300, d_loss: 1.0186, g_loss: 1.5351,D(x): 0.72, D(G(z)): 0.38
# Epoch 108, batch: 600, d_loss: 0.8019, g_loss: 1.6681,D(x): 0.76, D(G(z)): 0.30
# Epoch 109, batch: 300, d_loss: 0.7868, g_loss: 1.8319,D(x): 0.69, D(G(z)): 0.23
# Epoch 109, batch: 600, d_loss: 0.9087, g_loss: 1.5739,D(x): 0.77, D(G(z)): 0.36
# Epoch 110, batch: 300, d_loss: 0.8594, g_loss: 1.6622,D(x): 0.70, D(G(z)): 0.26
# Epoch 110, batch: 600, d_loss: 0.8786, g_loss: 1.9806,D(x): 0.76, D(G(z)): 0.33
# Epoch 111, batch: 300, d_loss: 1.0409, g_loss: 1.7150,D(x): 0.65, D(G(z)): 0.30
# Epoch 111, batch: 600, d_loss: 0.8371, g_loss: 2.1046,D(x): 0.70, D(G(z)): 0.26
# Epoch 112, batch: 300, d_loss: 0.8380, g_loss: 1.8573,D(x): 0.69, D(G(z)): 0.26
# Epoch 112, batch: 600, d_loss: 0.8109, g_loss: 1.6316,D(x): 0.73, D(G(z)): 0.28
# Epoch 113, batch: 300, d_loss: 0.8677, g_loss: 1.8473,D(x): 0.75, D(G(z)): 0.33
# Epoch 113, batch: 600, d_loss: 0.9179, g_loss: 1.5578,D(x): 0.72, D(G(z)): 0.34
# Epoch 114, batch: 300, d_loss: 0.9387, g_loss: 1.2547,D(x): 0.74, D(G(z)): 0.36
# Epoch 114, batch: 600, d_loss: 0.8764, g_loss: 1.7090,D(x): 0.65, D(G(z)): 0.22
# Epoch 115, batch: 300, d_loss: 0.9822, g_loss: 2.0563,D(x): 0.62, D(G(z)): 0.24
# Epoch 115, batch: 600, d_loss: 0.9081, g_loss: 1.5883,D(x): 0.67, D(G(z)): 0.27
# Epoch 116, batch: 300, d_loss: 0.9154, g_loss: 1.6458,D(x): 0.74, D(G(z)): 0.34
# Epoch 116, batch: 600, d_loss: 0.9070, g_loss: 1.4471,D(x): 0.72, D(G(z)): 0.32
# Epoch 117, batch: 300, d_loss: 0.8336, g_loss: 1.4521,D(x): 0.74, D(G(z)): 0.31
# Epoch 117, batch: 600, d_loss: 0.8591, g_loss: 1.4846,D(x): 0.70, D(G(z)): 0.26
# Epoch 118, batch: 300, d_loss: 0.9028, g_loss: 1.4132,D(x): 0.69, D(G(z)): 0.28
# Epoch 118, batch: 600, d_loss: 0.8342, g_loss: 1.5627,D(x): 0.77, D(G(z)): 0.34
# Epoch 119, batch: 300, d_loss: 0.8517, g_loss: 1.6878,D(x): 0.70, D(G(z)): 0.29
# Epoch 119, batch: 600, d_loss: 0.8754, g_loss: 1.7319,D(x): 0.72, D(G(z)): 0.30
# Epoch 120, batch: 300, d_loss: 0.9689, g_loss: 1.7240,D(x): 0.76, D(G(z)): 0.39
# Epoch 120, batch: 600, d_loss: 0.8096, g_loss: 1.7629,D(x): 0.73, D(G(z)): 0.27
# Epoch 121, batch: 300, d_loss: 0.8277, g_loss: 1.6219,D(x): 0.71, D(G(z)): 0.28
# Epoch 121, batch: 600, d_loss: 1.0936, g_loss: 1.3477,D(x): 0.68, D(G(z)): 0.37
# Epoch 122, batch: 300, d_loss: 0.9407, g_loss: 1.5600,D(x): 0.76, D(G(z)): 0.37
# Epoch 122, batch: 600, d_loss: 0.9974, g_loss: 1.5683,D(x): 0.71, D(G(z)): 0.35
# Epoch 123, batch: 300, d_loss: 0.7847, g_loss: 1.8835,D(x): 0.69, D(G(z)): 0.20
# Epoch 123, batch: 600, d_loss: 0.8555, g_loss: 1.7277,D(x): 0.64, D(G(z)): 0.21
# Epoch 124, batch: 300, d_loss: 0.8132, g_loss: 1.7251,D(x): 0.73, D(G(z)): 0.29
# Epoch 124, batch: 600, d_loss: 0.8948, g_loss: 1.2818,D(x): 0.69, D(G(z)): 0.27
# Epoch 125, batch: 300, d_loss: 0.9270, g_loss: 1.6538,D(x): 0.66, D(G(z)): 0.27
# Epoch 125, batch: 600, d_loss: 0.8745, g_loss: 1.6809,D(x): 0.75, D(G(z)): 0.34
# Epoch 126, batch: 300, d_loss: 0.8622, g_loss: 1.5260,D(x): 0.68, D(G(z)): 0.26
# Epoch 126, batch: 600, d_loss: 1.1063, g_loss: 2.0103,D(x): 0.54, D(G(z)): 0.21
# Epoch 127, batch: 300, d_loss: 0.8962, g_loss: 1.5638,D(x): 0.72, D(G(z)): 0.30
# Epoch 127, batch: 600, d_loss: 0.9302, g_loss: 1.3227,D(x): 0.67, D(G(z)): 0.27
# Epoch 128, batch: 300, d_loss: 0.8993, g_loss: 1.7401,D(x): 0.73, D(G(z)): 0.32
# Epoch 128, batch: 600, d_loss: 0.8612, g_loss: 1.7642,D(x): 0.71, D(G(z)): 0.30
# Epoch 129, batch: 300, d_loss: 0.8565, g_loss: 1.7704,D(x): 0.73, D(G(z)): 0.30
# Epoch 129, batch: 600, d_loss: 0.9172, g_loss: 1.5082,D(x): 0.68, D(G(z)): 0.27
# Epoch 130, batch: 300, d_loss: 0.7878, g_loss: 1.7325,D(x): 0.77, D(G(z)): 0.31
# Epoch 130, batch: 600, d_loss: 0.9490, g_loss: 1.4411,D(x): 0.70, D(G(z)): 0.34
# Epoch 131, batch: 300, d_loss: 0.8583, g_loss: 1.5481,D(x): 0.67, D(G(z)): 0.24
# Epoch 131, batch: 600, d_loss: 0.9652, g_loss: 1.7416,D(x): 0.70, D(G(z)): 0.31
# Epoch 132, batch: 300, d_loss: 0.8578, g_loss: 1.8524,D(x): 0.69, D(G(z)): 0.27
# Epoch 132, batch: 600, d_loss: 0.8615, g_loss: 1.5194,D(x): 0.76, D(G(z)): 0.34
# Epoch 133, batch: 300, d_loss: 0.9884, g_loss: 1.6413,D(x): 0.65, D(G(z)): 0.31
# Epoch 133, batch: 600, d_loss: 0.9146, g_loss: 1.8934,D(x): 0.70, D(G(z)): 0.30
# Epoch 134, batch: 300, d_loss: 0.9430, g_loss: 1.8332,D(x): 0.63, D(G(z)): 0.23
# Epoch 134, batch: 600, d_loss: 0.8651, g_loss: 1.5444,D(x): 0.71, D(G(z)): 0.29
# Epoch 135, batch: 300, d_loss: 0.8212, g_loss: 1.6686,D(x): 0.71, D(G(z)): 0.27
# Epoch 135, batch: 600, d_loss: 0.7811, g_loss: 1.9201,D(x): 0.73, D(G(z)): 0.26
# Epoch 136, batch: 300, d_loss: 0.8533, g_loss: 1.4940,D(x): 0.66, D(G(z)): 0.22
# Epoch 136, batch: 600, d_loss: 0.9565, g_loss: 1.8393,D(x): 0.68, D(G(z)): 0.27
# Epoch 137, batch: 300, d_loss: 0.9342, g_loss: 1.6522,D(x): 0.61, D(G(z)): 0.21
# Epoch 137, batch: 600, d_loss: 0.8338, g_loss: 1.7468,D(x): 0.68, D(G(z)): 0.25
# Epoch 138, batch: 300, d_loss: 0.7736, g_loss: 1.7290,D(x): 0.73, D(G(z)): 0.26
# Epoch 138, batch: 600, d_loss: 0.7808, g_loss: 1.9063,D(x): 0.76, D(G(z)): 0.30
# Epoch 139, batch: 300, d_loss: 0.9255, g_loss: 1.4766,D(x): 0.79, D(G(z)): 0.37
# Epoch 139, batch: 600, d_loss: 0.8544, g_loss: 1.8013,D(x): 0.72, D(G(z)): 0.29
# Epoch 140, batch: 300, d_loss: 0.8147, g_loss: 1.6591,D(x): 0.75, D(G(z)): 0.28
# Epoch 140, batch: 600, d_loss: 0.8956, g_loss: 2.0392,D(x): 0.68, D(G(z)): 0.26
# Epoch 141, batch: 300, d_loss: 0.9778, g_loss: 1.7045,D(x): 0.69, D(G(z)): 0.31
# Epoch 141, batch: 600, d_loss: 0.8373, g_loss: 1.5364,D(x): 0.75, D(G(z)): 0.31
# Epoch 142, batch: 300, d_loss: 0.9817, g_loss: 1.7923,D(x): 0.73, D(G(z)): 0.35
# Epoch 142, batch: 600, d_loss: 0.9402, g_loss: 1.4461,D(x): 0.71, D(G(z)): 0.32
# Epoch 143, batch: 300, d_loss: 0.9491, g_loss: 1.7099,D(x): 0.74, D(G(z)): 0.36
# Epoch 143, batch: 600, d_loss: 0.7838, g_loss: 1.3127,D(x): 0.76, D(G(z)): 0.30
# Epoch 144, batch: 300, d_loss: 0.7829, g_loss: 1.7775,D(x): 0.72, D(G(z)): 0.28
# Epoch 144, batch: 600, d_loss: 0.9998, g_loss: 1.7099,D(x): 0.70, D(G(z)): 0.33
# Epoch 145, batch: 300, d_loss: 0.9516, g_loss: 1.5317,D(x): 0.74, D(G(z)): 0.37
# Epoch 145, batch: 600, d_loss: 0.8581, g_loss: 1.9650,D(x): 0.65, D(G(z)): 0.22
# Epoch 146, batch: 300, d_loss: 1.0490, g_loss: 1.6192,D(x): 0.69, D(G(z)): 0.37
# Epoch 146, batch: 600, d_loss: 0.9700, g_loss: 1.6156,D(x): 0.68, D(G(z)): 0.30
# Epoch 147, batch: 300, d_loss: 0.7300, g_loss: 2.0111,D(x): 0.77, D(G(z)): 0.26
# Epoch 147, batch: 600, d_loss: 0.8580, g_loss: 2.2481,D(x): 0.72, D(G(z)): 0.28
# Epoch 148, batch: 300, d_loss: 0.9495, g_loss: 1.1615,D(x): 0.71, D(G(z)): 0.32
# Epoch 148, batch: 600, d_loss: 0.7737, g_loss: 1.7206,D(x): 0.72, D(G(z)): 0.26
# Epoch 149, batch: 300, d_loss: 0.8513, g_loss: 1.7862,D(x): 0.75, D(G(z)): 0.31
# Epoch 149, batch: 600, d_loss: 0.9719, g_loss: 1.3593,D(x): 0.76, D(G(z)): 0.37
# Epoch 150, batch: 300, d_loss: 0.7189, g_loss: 1.9057,D(x): 0.74, D(G(z)): 0.26
# Epoch 150, batch: 600, d_loss: 0.8305, g_loss: 1.8295,D(x): 0.73, D(G(z)): 0.29
# Epoch 151, batch: 300, d_loss: 0.8051, g_loss: 1.8042,D(x): 0.73, D(G(z)): 0.29
# Epoch 151, batch: 600, d_loss: 0.8408, g_loss: 1.8500,D(x): 0.74, D(G(z)): 0.30
# Epoch 152, batch: 300, d_loss: 0.9018, g_loss: 1.8132,D(x): 0.68, D(G(z)): 0.27
# Epoch 152, batch: 600, d_loss: 1.0333, g_loss: 1.8671,D(x): 0.66, D(G(z)): 0.29
# Epoch 153, batch: 300, d_loss: 0.7938, g_loss: 1.4248,D(x): 0.72, D(G(z)): 0.26
# Epoch 153, batch: 600, d_loss: 0.7911, g_loss: 1.9870,D(x): 0.81, D(G(z)): 0.33
# Epoch 154, batch: 300, d_loss: 0.8114, g_loss: 1.8803,D(x): 0.75, D(G(z)): 0.32
# Epoch 154, batch: 600, d_loss: 0.9749, g_loss: 1.8108,D(x): 0.62, D(G(z)): 0.23
# Epoch 155, batch: 300, d_loss: 0.9810, g_loss: 1.5319,D(x): 0.76, D(G(z)): 0.36
# Epoch 155, batch: 600, d_loss: 0.9764, g_loss: 1.9677,D(x): 0.65, D(G(z)): 0.26
# Epoch 156, batch: 300, d_loss: 0.8852, g_loss: 1.9410,D(x): 0.67, D(G(z)): 0.25
# Epoch 156, batch: 600, d_loss: 0.8713, g_loss: 1.7935,D(x): 0.72, D(G(z)): 0.29
# Epoch 157, batch: 300, d_loss: 0.7933, g_loss: 1.6682,D(x): 0.74, D(G(z)): 0.28
# Epoch 157, batch: 600, d_loss: 0.9812, g_loss: 1.5272,D(x): 0.73, D(G(z)): 0.36
# Epoch 158, batch: 300, d_loss: 0.9764, g_loss: 1.2913,D(x): 0.80, D(G(z)): 0.39
# Epoch 158, batch: 600, d_loss: 0.7991, g_loss: 2.0387,D(x): 0.70, D(G(z)): 0.25
# Epoch 159, batch: 300, d_loss: 0.9398, g_loss: 1.8302,D(x): 0.69, D(G(z)): 0.30
# Epoch 159, batch: 600, d_loss: 0.8546, g_loss: 1.7204,D(x): 0.71, D(G(z)): 0.30
# Epoch 160, batch: 300, d_loss: 0.8334, g_loss: 1.5071,D(x): 0.76, D(G(z)): 0.29
# Epoch 160, batch: 600, d_loss: 0.8453, g_loss: 1.7395,D(x): 0.71, D(G(z)): 0.29
# Epoch 161, batch: 300, d_loss: 0.8002, g_loss: 1.9746,D(x): 0.71, D(G(z)): 0.24
# Epoch 161, batch: 600, d_loss: 0.9715, g_loss: 1.6548,D(x): 0.72, D(G(z)): 0.35
# Epoch 162, batch: 300, d_loss: 0.8900, g_loss: 2.0705,D(x): 0.65, D(G(z)): 0.22
# Epoch 162, batch: 600, d_loss: 0.8648, g_loss: 2.1487,D(x): 0.68, D(G(z)): 0.24
# Epoch 163, batch: 300, d_loss: 0.9270, g_loss: 1.7269,D(x): 0.70, D(G(z)): 0.32
# Epoch 163, batch: 600, d_loss: 0.9892, g_loss: 1.4371,D(x): 0.65, D(G(z)): 0.28
# Epoch 164, batch: 300, d_loss: 0.7746, g_loss: 1.5299,D(x): 0.76, D(G(z)): 0.29
# Epoch 164, batch: 600, d_loss: 0.9741, g_loss: 1.6499,D(x): 0.65, D(G(z)): 0.25
# Epoch 165, batch: 300, d_loss: 0.8907, g_loss: 1.9624,D(x): 0.69, D(G(z)): 0.27
# Epoch 165, batch: 600, d_loss: 0.8997, g_loss: 1.6306,D(x): 0.74, D(G(z)): 0.33
# Epoch 166, batch: 300, d_loss: 0.9191, g_loss: 1.6887,D(x): 0.69, D(G(z)): 0.28
# Epoch 166, batch: 600, d_loss: 0.7806, g_loss: 1.8437,D(x): 0.74, D(G(z)): 0.28
# Epoch 167, batch: 300, d_loss: 0.7978, g_loss: 1.5541,D(x): 0.66, D(G(z)): 0.20
# Epoch 167, batch: 600, d_loss: 0.8416, g_loss: 1.7018,D(x): 0.75, D(G(z)): 0.33
# Epoch 168, batch: 300, d_loss: 0.9366, g_loss: 1.3555,D(x): 0.76, D(G(z)): 0.37
# Epoch 168, batch: 600, d_loss: 0.9504, g_loss: 1.5267,D(x): 0.77, D(G(z)): 0.35
# Epoch 169, batch: 300, d_loss: 0.8118, g_loss: 2.0452,D(x): 0.69, D(G(z)): 0.24
# Epoch 169, batch: 600, d_loss: 0.9264, g_loss: 1.8109,D(x): 0.72, D(G(z)): 0.30
# Epoch 170, batch: 300, d_loss: 0.9036, g_loss: 1.7344,D(x): 0.70, D(G(z)): 0.27
# Epoch 170, batch: 600, d_loss: 0.8004, g_loss: 1.8705,D(x): 0.72, D(G(z)): 0.26
# Epoch 171, batch: 300, d_loss: 0.8444, g_loss: 1.6232,D(x): 0.72, D(G(z)): 0.25
# Epoch 171, batch: 600, d_loss: 0.8851, g_loss: 1.5728,D(x): 0.71, D(G(z)): 0.29
# Epoch 172, batch: 300, d_loss: 0.8562, g_loss: 1.8509,D(x): 0.71, D(G(z)): 0.28
# Epoch 172, batch: 600, d_loss: 0.8434, g_loss: 1.7962,D(x): 0.71, D(G(z)): 0.25
# Epoch 173, batch: 300, d_loss: 0.8812, g_loss: 1.9078,D(x): 0.70, D(G(z)): 0.28
# Epoch 173, batch: 600, d_loss: 0.8018, g_loss: 1.7541,D(x): 0.70, D(G(z)): 0.25
# Epoch 174, batch: 300, d_loss: 0.8234, g_loss: 2.0424,D(x): 0.70, D(G(z)): 0.26
# Epoch 174, batch: 600, d_loss: 0.9841, g_loss: 1.2922,D(x): 0.69, D(G(z)): 0.29
# Epoch 175, batch: 300, d_loss: 0.8777, g_loss: 1.9036,D(x): 0.72, D(G(z)): 0.28
# Epoch 175, batch: 600, d_loss: 0.8121, g_loss: 1.8875,D(x): 0.67, D(G(z)): 0.22
# Epoch 176, batch: 300, d_loss: 0.9086, g_loss: 1.6932,D(x): 0.74, D(G(z)): 0.30
# Epoch 176, batch: 600, d_loss: 0.7009, g_loss: 1.7327,D(x): 0.82, D(G(z)): 0.32
# Epoch 177, batch: 300, d_loss: 0.9163, g_loss: 1.8995,D(x): 0.67, D(G(z)): 0.24
# Epoch 177, batch: 600, d_loss: 0.9568, g_loss: 2.1236,D(x): 0.73, D(G(z)): 0.34
# Epoch 178, batch: 300, d_loss: 0.7856, g_loss: 1.5497,D(x): 0.77, D(G(z)): 0.28
# Epoch 178, batch: 600, d_loss: 0.7954, g_loss: 2.4576,D(x): 0.79, D(G(z)): 0.33
# Epoch 179, batch: 300, d_loss: 0.9221, g_loss: 1.7520,D(x): 0.71, D(G(z)): 0.31
# Epoch 179, batch: 600, d_loss: 0.7616, g_loss: 1.7615,D(x): 0.72, D(G(z)): 0.23
# Epoch 180, batch: 300, d_loss: 0.7576, g_loss: 1.9299,D(x): 0.74, D(G(z)): 0.27
# Epoch 180, batch: 600, d_loss: 0.9617, g_loss: 1.9975,D(x): 0.68, D(G(z)): 0.28
# Epoch 181, batch: 300, d_loss: 0.8992, g_loss: 1.6562,D(x): 0.72, D(G(z)): 0.28
# Epoch 181, batch: 600, d_loss: 0.8130, g_loss: 1.7514,D(x): 0.75, D(G(z)): 0.29
# Epoch 182, batch: 300, d_loss: 0.8753, g_loss: 1.8340,D(x): 0.73, D(G(z)): 0.29
# Epoch 182, batch: 600, d_loss: 0.9142, g_loss: 1.6572,D(x): 0.70, D(G(z)): 0.30
# Epoch 183, batch: 300, d_loss: 0.8805, g_loss: 1.9628,D(x): 0.72, D(G(z)): 0.31
# Epoch 183, batch: 600, d_loss: 0.9888, g_loss: 1.7915,D(x): 0.75, D(G(z)): 0.37
# Epoch 184, batch: 300, d_loss: 0.8768, g_loss: 1.7439,D(x): 0.68, D(G(z)): 0.28
# Epoch 184, batch: 600, d_loss: 0.9605, g_loss: 1.7807,D(x): 0.68, D(G(z)): 0.29
# Epoch 185, batch: 300, d_loss: 0.7947, g_loss: 1.7151,D(x): 0.77, D(G(z)): 0.31
# Epoch 185, batch: 600, d_loss: 0.8736, g_loss: 1.6242,D(x): 0.77, D(G(z)): 0.33
# Epoch 186, batch: 300, d_loss: 0.8126, g_loss: 1.7500,D(x): 0.72, D(G(z)): 0.28
# Epoch 186, batch: 600, d_loss: 0.8923, g_loss: 1.9283,D(x): 0.74, D(G(z)): 0.29
# Epoch 187, batch: 300, d_loss: 1.0539, g_loss: 1.9339,D(x): 0.60, D(G(z)): 0.21
# Epoch 187, batch: 600, d_loss: 0.8017, g_loss: 2.0533,D(x): 0.79, D(G(z)): 0.29
# Epoch 188, batch: 300, d_loss: 0.7418, g_loss: 1.7443,D(x): 0.73, D(G(z)): 0.24
# Epoch 188, batch: 600, d_loss: 0.9510, g_loss: 1.5422,D(x): 0.74, D(G(z)): 0.34
# Epoch 189, batch: 300, d_loss: 0.9035, g_loss: 1.8700,D(x): 0.74, D(G(z)): 0.33
# Epoch 189, batch: 600, d_loss: 0.8717, g_loss: 1.9577,D(x): 0.75, D(G(z)): 0.33
# Epoch 190, batch: 300, d_loss: 0.9669, g_loss: 2.3042,D(x): 0.61, D(G(z)): 0.20
# Epoch 190, batch: 600, d_loss: 0.8451, g_loss: 1.7884,D(x): 0.73, D(G(z)): 0.32
# Epoch 191, batch: 300, d_loss: 0.7712, g_loss: 1.6104,D(x): 0.77, D(G(z)): 0.30
# Epoch 191, batch: 600, d_loss: 0.9261, g_loss: 2.0693,D(x): 0.69, D(G(z)): 0.29
# Epoch 192, batch: 300, d_loss: 0.7996, g_loss: 2.0222,D(x): 0.74, D(G(z)): 0.28
# Epoch 192, batch: 600, d_loss: 0.9529, g_loss: 1.7624,D(x): 0.74, D(G(z)): 0.34
# Epoch 193, batch: 300, d_loss: 0.8038, g_loss: 1.9562,D(x): 0.69, D(G(z)): 0.22
# Epoch 193, batch: 600, d_loss: 0.8374, g_loss: 1.8175,D(x): 0.72, D(G(z)): 0.26
# Epoch 194, batch: 300, d_loss: 0.9081, g_loss: 2.1285,D(x): 0.69, D(G(z)): 0.26
# Epoch 194, batch: 600, d_loss: 0.8196, g_loss: 1.5350,D(x): 0.75, D(G(z)): 0.29
# Epoch 195, batch: 300, d_loss: 0.9270, g_loss: 1.8061,D(x): 0.70, D(G(z)): 0.27
# Epoch 195, batch: 600, d_loss: 0.8452, g_loss: 1.9930,D(x): 0.75, D(G(z)): 0.28
# Epoch 196, batch: 300, d_loss: 0.8197, g_loss: 1.7256,D(x): 0.72, D(G(z)): 0.28
# Epoch 196, batch: 600, d_loss: 0.8366, g_loss: 1.5208,D(x): 0.81, D(G(z)): 0.37
# Epoch 197, batch: 300, d_loss: 0.9182, g_loss: 1.7987,D(x): 0.66, D(G(z)): 0.26
# Epoch 197, batch: 600, d_loss: 0.8119, g_loss: 1.6888,D(x): 0.70, D(G(z)): 0.26
# Epoch 198, batch: 300, d_loss: 0.7437, g_loss: 1.8883,D(x): 0.74, D(G(z)): 0.25
# Epoch 198, batch: 600, d_loss: 0.9651, g_loss: 2.0062,D(x): 0.80, D(G(z)): 0.38
# Epoch 199, batch: 300, d_loss: 1.0154, g_loss: 1.6825,D(x): 0.70, D(G(z)): 0.33
# Epoch 199, batch: 600, d_loss: 0.9498, g_loss: 1.6196,D(x): 0.71, D(G(z)): 0.35

# %% [markdown]
# # CNN

# %%
class DisCriminator(nn.Module): #刻意弱化他
  def __init__(self):
    super(DisCriminator, self).__init__()
    self.conv1 = nn.Conv2d(
        in_channels = 1,
        out_channels = 64,
        kernel_size= 5, #看的範圍大，所以學的不好->讓generator有辦法train
        stride = 2,
        padding = 2,
        bias = True
    )
    self.leaky_relu = nn.LeakyReLU()
    self.dropout_2d = nn.Dropout2d(0.3)
    self.conv2 = nn.Conv2d(
        in_channels = 64,
        out_channels = 128,
        kernel_size= 5, 
        stride = 2,
        padding = 2,
        bias = True
    )
    self.linear1 = nn.Linear(128*7*7, 1, bias=True)
    self.sigmoid = nn.Sigmoid()
  def forward(self, x):
    out = self.conv1(x)
    out = self.leaky_relu(out)
    out = self.dropout_2d(out)
    out = self.conv2(out)
    out = self.leaky_relu(out)
    out = self.dropout_2d(out)
    out = out.view(-1, 128*7*7)
    out = self.linear1(out)
    out = self.sigmoid(out)
    return out

# %%
class Generator(nn.Module):
  def __init__(self, latent_dim = 100, batchnorm= True):
    super(Generator, self).__init__()
    self.latent_dim = latent_dim
    self.batchnorm = batchnorm
    self.linear1 = nn.Linear(latent_dim, 7*7*256, bias=False)
    self.bn1d1 = nn.BatchNorm1d(256*7*7) if batchnorm else None
    self.leaky_relu = nn.LeakyReLU()
    self.conv1 = nn.Conv2d(
        in_channels = 256,
        out_channels = 128,
        kernel_size = 5,
        stride = 1,
        padding = 2,
        bias = False
    )
    self.bn2d1 = nn.BatchNorm2d(128) if batchnorm else None
    self.conv2 = nn.ConvTranspose2d(
        in_channels =128,
        out_channels = 64,
        kernel_size = 4,
        stride = 2,
        padding = 1,
        bias = False
    )
    self.bn2d2 = nn.BatchNorm2d(64) if batchnorm else None
    self.conv3 = nn.ConvTranspose2d(
    in_channels =64,
    out_channels = 1,
    kernel_size = 4,
    stride = 2,
    padding = 1,
    bias = False
    )
    self.tanh = nn.Tanh()
  def forward(self, x):
    out = self.linear1(x)
    if self.batchnorm:
      out = self.bn1d1(out)
    out = self.leaky_relu(out)
    out = out.view((-1, 256, 7, 7))
    out = self.conv1(out)
    if self.batchnorm:
      out = self.bn2d1(out)
    out = self.leaky_relu(out)
    out = self.conv2(out)
    if self.batchnorm:
      out = self.bn2d2(out)
    out = self.leaky_relu(out)
    out = self.conv3(out)
    out = self.tanh(out)
    return out

# %%
DCG = Generator()
DCD = DisCriminator()

# %%
if torch.cuda.is_available():
  DCG.cuda()
  DCD.cuda()

# %%
dcd_opt = torch.optim.Adam(DCD.parameters(),lr=0.001, betas=(0.5,0.999))
dcg_opt = torch.optim.Adam(DCG.parameters(),lr=0.0001, betas=(0.5,0.999))

# %%
for epoch in range(50):
  for i, (images,_) in enumerate(data_loader):
    batch_size = images.size(0)
    images = to_var(images)

    real_labels = to_var(torch.ones(batch_size,1))
    fake_labels = to_var(torch.zeros(batch_size,1))

    outputs = DCD(images)
    d_loss_real = loss_fn(outputs, real_labels)
    real_score = outputs
    
    z = to_var(torch.randn(batch_size, 100))     
    fake_images = DCG(z)
    outputs = DCD(fake_images)
    d_loss_fake = loss_fn(outputs, fake_labels)
    fake_score = outputs

    d_loss = d_loss_real+d_loss_fake
    DCD.zero_grad()
    d_loss.backward()
    dcd_opt.step()

    z = to_var(torch.randn(batch_size, 100))
    fake_images = DCG(z)
    outputs = DCD(fake_images)

    g_loss = loss_fn(outputs, real_labels)
    DCD.zero_grad()
    DCG.zero_grad()
    g_loss.backward()
    dcg_opt.step()

    if (i+1)%300 == 0:
      print("Epoch %-3d, batch: %-3d, d_loss: %-.4f, g_loss: %-.4f,"
      "D(x): %-.2f, D(G(z)): %-.2f"
      %(epoch,i+1,d_loss.data,g_loss.data,real_score.data.mean(),fake_score.data.mean()))
  if epoch == 0:
    images = images.view(images.size(0), 1, 28, 28)
    save_image(denorm(images),"/content/data1/real_images.png")
  fake_images = fake_images.view(fake_images.size(0), 1, 28, 28)
  save_image(denorm(fake_images),"/content/data1/fake_images-%d.png"%(epoch+1))
# Out:
# Epoch 0  , batch: 300, d_loss: 0.8629, g_loss: 1.7478,D(x): 0.56, D(G(z)): 0.10
# Epoch 0  , batch: 600, d_loss: 0.7261, g_loss: 1.9313,D(x): 0.74, D(G(z)): 0.25
# Epoch 1  , batch: 300, d_loss: 0.8500, g_loss: 1.2757,D(x): 0.66, D(G(z)): 0.27
# Epoch 1  , batch: 600, d_loss: 0.8623, g_loss: 1.4074,D(x): 0.68, D(G(z)): 0.29
# Epoch 2  , batch: 300, d_loss: 0.7339, g_loss: 1.7774,D(x): 0.71, D(G(z)): 0.25
# Epoch 2  , batch: 600, d_loss: 0.9170, g_loss: 1.8160,D(x): 0.74, D(G(z)): 0.35
# Epoch 3  , batch: 300, d_loss: 0.8777, g_loss: 1.5642,D(x): 0.71, D(G(z)): 0.29
# Epoch 3  , batch: 600, d_loss: 0.8016, g_loss: 1.6359,D(x): 0.75, D(G(z)): 0.29
# Epoch 4  , batch: 300, d_loss: 0.9661, g_loss: 1.6579,D(x): 0.71, D(G(z)): 0.32
# Epoch 4  , batch: 600, d_loss: 0.8975, g_loss: 1.3144,D(x): 0.63, D(G(z)): 0.24
# Epoch 5  , batch: 300, d_loss: 0.8548, g_loss: 1.3861,D(x): 0.63, D(G(z)): 0.21
# Epoch 5  , batch: 600, d_loss: 0.9315, g_loss: 1.2002,D(x): 0.62, D(G(z)): 0.21
# Epoch 6  , batch: 300, d_loss: 0.7656, g_loss: 1.8003,D(x): 0.76, D(G(z)): 0.30
# Epoch 6  , batch: 600, d_loss: 0.9070, g_loss: 1.2914,D(x): 0.65, D(G(z)): 0.28
# Epoch 7  , batch: 300, d_loss: 0.9578, g_loss: 1.3233,D(x): 0.68, D(G(z)): 0.32
# Epoch 7  , batch: 600, d_loss: 0.8353, g_loss: 1.5352,D(x): 0.79, D(G(z)): 0.35
# Epoch 8  , batch: 300, d_loss: 0.8674, g_loss: 1.5616,D(x): 0.70, D(G(z)): 0.29
# Epoch 8  , batch: 600, d_loss: 0.9203, g_loss: 1.8686,D(x): 0.70, D(G(z)): 0.28
# Epoch 9  , batch: 300, d_loss: 0.9374, g_loss: 1.5722,D(x): 0.68, D(G(z)): 0.27
# Epoch 9  , batch: 600, d_loss: 0.8223, g_loss: 1.6701,D(x): 0.70, D(G(z)): 0.26
# Epoch 10 , batch: 300, d_loss: 0.8009, g_loss: 1.7032,D(x): 0.76, D(G(z)): 0.31
# Epoch 10 , batch: 600, d_loss: 0.9606, g_loss: 1.4936,D(x): 0.64, D(G(z)): 0.23
# Epoch 11 , batch: 300, d_loss: 0.7761, g_loss: 1.4527,D(x): 0.69, D(G(z)): 0.24
# Epoch 11 , batch: 600, d_loss: 0.6895, g_loss: 1.9391,D(x): 0.76, D(G(z)): 0.25
# Epoch 12 , batch: 300, d_loss: 0.9586, g_loss: 2.1502,D(x): 0.76, D(G(z)): 0.36
# Epoch 12 , batch: 600, d_loss: 0.7514, g_loss: 1.9168,D(x): 0.79, D(G(z)): 0.32
# Epoch 13 , batch: 300, d_loss: 0.8831, g_loss: 1.6110,D(x): 0.64, D(G(z)): 0.19
# Epoch 13 , batch: 600, d_loss: 0.7281, g_loss: 1.3739,D(x): 0.73, D(G(z)): 0.24
# Epoch 14 , batch: 300, d_loss: 0.8238, g_loss: 1.5416,D(x): 0.65, D(G(z)): 0.20
# Epoch 14 , batch: 600, d_loss: 0.8180, g_loss: 1.7491,D(x): 0.77, D(G(z)): 0.31
# Epoch 15 , batch: 300, d_loss: 0.8407, g_loss: 1.3909,D(x): 0.68, D(G(z)): 0.24
# Epoch 15 , batch: 600, d_loss: 0.8298, g_loss: 1.2161,D(x): 0.64, D(G(z)): 0.15
# Epoch 16 , batch: 300, d_loss: 0.7965, g_loss: 1.9859,D(x): 0.73, D(G(z)): 0.25
# Epoch 16 , batch: 600, d_loss: 0.7751, g_loss: 1.3867,D(x): 0.70, D(G(z)): 0.22
# Epoch 17 , batch: 300, d_loss: 0.8143, g_loss: 2.0051,D(x): 0.67, D(G(z)): 0.20
# Epoch 17 , batch: 600, d_loss: 0.7303, g_loss: 2.0174,D(x): 0.72, D(G(z)): 0.19
# Epoch 18 , batch: 300, d_loss: 0.8064, g_loss: 1.9080,D(x): 0.79, D(G(z)): 0.30
# Epoch 18 , batch: 600, d_loss: 0.7946, g_loss: 2.1692,D(x): 0.85, D(G(z)): 0.35
# Epoch 19 , batch: 300, d_loss: 0.8288, g_loss: 1.9738,D(x): 0.71, D(G(z)): 0.23
# Epoch 19 , batch: 600, d_loss: 0.6539, g_loss: 1.8259,D(x): 0.78, D(G(z)): 0.22
# Epoch 20 , batch: 300, d_loss: 0.8133, g_loss: 2.1926,D(x): 0.75, D(G(z)): 0.25
# Epoch 20 , batch: 600, d_loss: 0.9004, g_loss: 1.5177,D(x): 0.65, D(G(z)): 0.19
# Epoch 21 , batch: 300, d_loss: 0.8806, g_loss: 1.8579,D(x): 0.65, D(G(z)): 0.18
# Epoch 21 , batch: 600, d_loss: 0.7855, g_loss: 1.9460,D(x): 0.71, D(G(z)): 0.24
# Epoch 22 , batch: 300, d_loss: 0.7899, g_loss: 2.4498,D(x): 0.84, D(G(z)): 0.34
# Epoch 22 , batch: 600, d_loss: 0.6025, g_loss: 1.8053,D(x): 0.76, D(G(z)): 0.15
# Epoch 23 , batch: 300, d_loss: 0.9260, g_loss: 1.3862,D(x): 0.66, D(G(z)): 0.20
# Epoch 23 , batch: 600, d_loss: 0.7227, g_loss: 2.4679,D(x): 0.86, D(G(z)): 0.33
# Epoch 24 , batch: 300, d_loss: 0.7319, g_loss: 1.9317,D(x): 0.73, D(G(z)): 0.22
# Epoch 24 , batch: 600, d_loss: 0.7186, g_loss: 2.3311,D(x): 0.72, D(G(z)): 0.18
# Epoch 25 , batch: 300, d_loss: 0.6435, g_loss: 2.4342,D(x): 0.84, D(G(z)): 0.25
# Epoch 25 , batch: 600, d_loss: 0.6681, g_loss: 2.0414,D(x): 0.75, D(G(z)): 0.19
# Epoch 26 , batch: 300, d_loss: 0.6308, g_loss: 2.2875,D(x): 0.78, D(G(z)): 0.21
# Epoch 26 , batch: 600, d_loss: 0.7214, g_loss: 2.4822,D(x): 0.70, D(G(z)): 0.14
# Epoch 27 , batch: 300, d_loss: 0.7492, g_loss: 2.2619,D(x): 0.78, D(G(z)): 0.26
# Epoch 27 , batch: 600, d_loss: 0.7217, g_loss: 2.0939,D(x): 0.75, D(G(z)): 0.20
# Epoch 28 , batch: 300, d_loss: 0.6977, g_loss: 1.9448,D(x): 0.81, D(G(z)): 0.26
# Epoch 28 , batch: 600, d_loss: 0.6773, g_loss: 2.1885,D(x): 0.77, D(G(z)): 0.17
# Epoch 29 , batch: 300, d_loss: 0.6958, g_loss: 2.3250,D(x): 0.75, D(G(z)): 0.22
# Epoch 29 , batch: 600, d_loss: 0.7380, g_loss: 2.5306,D(x): 0.68, D(G(z)): 0.14
# Epoch 30 , batch: 300, d_loss: 0.5953, g_loss: 2.8519,D(x): 0.77, D(G(z)): 0.17
# Epoch 30 , batch: 600, d_loss: 0.6374, g_loss: 2.0830,D(x): 0.83, D(G(z)): 0.25
# Epoch 31 , batch: 300, d_loss: 0.6975, g_loss: 1.9561,D(x): 0.74, D(G(z)): 0.15
# Epoch 31 , batch: 600, d_loss: 0.6017, g_loss: 2.3846,D(x): 0.84, D(G(z)): 0.23
# Epoch 32 , batch: 300, d_loss: 0.7095, g_loss: 2.7886,D(x): 0.77, D(G(z)): 0.19
# Epoch 32 , batch: 600, d_loss: 0.7293, g_loss: 2.5550,D(x): 0.73, D(G(z)): 0.18
# Epoch 33 , batch: 300, d_loss: 0.5870, g_loss: 2.4171,D(x): 0.83, D(G(z)): 0.22
# Epoch 33 , batch: 600, d_loss: 0.7137, g_loss: 3.1600,D(x): 0.80, D(G(z)): 0.25
# Epoch 34 , batch: 300, d_loss: 0.6981, g_loss: 2.3700,D(x): 0.77, D(G(z)): 0.21
# Epoch 34 , batch: 600, d_loss: 0.6687, g_loss: 1.8758,D(x): 0.73, D(G(z)): 0.15
# Epoch 35 , batch: 300, d_loss: 0.5818, g_loss: 2.2537,D(x): 0.80, D(G(z)): 0.18
# Epoch 35 , batch: 600, d_loss: 0.6357, g_loss: 2.0748,D(x): 0.77, D(G(z)): 0.18
# Epoch 36 , batch: 300, d_loss: 0.6978, g_loss: 2.5033,D(x): 0.84, D(G(z)): 0.27
# Epoch 36 , batch: 600, d_loss: 0.7310, g_loss: 2.3970,D(x): 0.82, D(G(z)): 0.27
# Epoch 37 , batch: 300, d_loss: 0.6690, g_loss: 2.4771,D(x): 0.81, D(G(z)): 0.24
# Epoch 37 , batch: 600, d_loss: 0.5513, g_loss: 2.9232,D(x): 0.83, D(G(z)): 0.20
# Epoch 38 , batch: 300, d_loss: 0.7669, g_loss: 3.0047,D(x): 0.78, D(G(z)): 0.25
# Epoch 38 , batch: 600, d_loss: 0.6852, g_loss: 3.1099,D(x): 0.81, D(G(z)): 0.26
# Epoch 39 , batch: 300, d_loss: 0.5986, g_loss: 2.7688,D(x): 0.81, D(G(z)): 0.19
# Epoch 39 , batch: 600, d_loss: 0.5569, g_loss: 2.4968,D(x): 0.85, D(G(z)): 0.22
# Epoch 40 , batch: 300, d_loss: 0.6058, g_loss: 2.2337,D(x): 0.77, D(G(z)): 0.17
# Epoch 40 , batch: 600, d_loss: 0.5535, g_loss: 2.1264,D(x): 0.83, D(G(z)): 0.19
# Epoch 41 , batch: 300, d_loss: 0.6520, g_loss: 2.0423,D(x): 0.71, D(G(z)): 0.12
# Epoch 41 , batch: 600, d_loss: 0.5787, g_loss: 2.4706,D(x): 0.84, D(G(z)): 0.20
# Epoch 42 , batch: 300, d_loss: 0.5926, g_loss: 2.7917,D(x): 0.81, D(G(z)): 0.18
# Epoch 42 , batch: 600, d_loss: 0.7040, g_loss: 2.0614,D(x): 0.71, D(G(z)): 0.15
# Epoch 43 , batch: 300, d_loss: 0.5877, g_loss: 3.0091,D(x): 0.85, D(G(z)): 0.23
# Epoch 43 , batch: 600, d_loss: 0.5553, g_loss: 2.5968,D(x): 0.85, D(G(z)): 0.20
# Epoch 44 , batch: 300, d_loss: 0.5819, g_loss: 2.7614,D(x): 0.80, D(G(z)): 0.17
# Epoch 44 , batch: 600, d_loss: 0.7886, g_loss: 2.2367,D(x): 0.70, D(G(z)): 0.14
# Epoch 45 , batch: 300, d_loss: 0.7785, g_loss: 2.4003,D(x): 0.76, D(G(z)): 0.22
# Epoch 45 , batch: 600, d_loss: 0.5463, g_loss: 2.8861,D(x): 0.82, D(G(z)): 0.18
# Epoch 46 , batch: 300, d_loss: 0.6454, g_loss: 2.6136,D(x): 0.81, D(G(z)): 0.24
# Epoch 46 , batch: 600, d_loss: 0.6871, g_loss: 2.2897,D(x): 0.74, D(G(z)): 0.17
# Epoch 47 , batch: 300, d_loss: 0.5856, g_loss: 2.5284,D(x): 0.79, D(G(z)): 0.15
# Epoch 47 , batch: 600, d_loss: 0.6760, g_loss: 2.7800,D(x): 0.78, D(G(z)): 0.17
# Epoch 48 , batch: 300, d_loss: 0.5670, g_loss: 2.6573,D(x): 0.81, D(G(z)): 0.19
# Epoch 48 , batch: 600, d_loss: 0.5807, g_loss: 2.3745,D(x): 0.84, D(G(z)): 0.22
# Epoch 49 , batch: 300, d_loss: 0.5362, g_loss: 3.2884,D(x): 0.88, D(G(z)): 0.23
# Epoch 49 , batch: 600, d_loss: 0.6396, g_loss: 2.5229,D(x): 0.79, D(G(z)): 0.18
